# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def draw_pie(data,labels):
    #define Seaborn color palette to use
    colors = sns.color_palette('pastel')[0:5]
    #create pie chart
    plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
    plt.show()

# %%
sns.set_theme()

# %%
penguins_df = sns.load_dataset('penguins')
penguins_df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguins_df.describe(include='all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      344     344      342.000000     342.000000         342.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       152     168             NaN            NaN                NaN
# mean       NaN     NaN       43.921930      17.151170         200.915205
# std        NaN     NaN        5.459584       1.974793          14.061714
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.225000      15.600000         190.000000
# 50%        NaN     NaN       44.450000      17.300000         197.000000
# 75%        NaN     NaN       48.500000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex
# count    342.000000   333
# unique          NaN     2
# ...

# %%
data = list(penguins_df['species'].value_counts())
labels = list(penguins_df['species'].value_counts().index)
plt.title('Species pie chart')
draw_pie(data, labels);

# %%
sns.countplot(data = penguins_df, x ='species', hue ='sex');

# %%
data  = list(penguins_df['island'].value_counts())
labels = list(penguins_df['island'].value_counts().index)
plt.title('Island pie chart')
draw_pie(data,labels)

# %%
sns.countplot(data = penguins_df, x ='species', hue ='island');

# %%
sns.displot(data =penguins_df, x ='bill_length_mm',col ='species' ,kde = True);

# %%
sns.boxplot(data = penguins_df, x = 'species', y='bill_length_mm', hue='sex');

# %%
penguins_fg = sns.FacetGrid(data = penguins_df, row='sex' ,col = 'island')
penguins_fg.map(sns.scatterplot, 'bill_length_mm', "bill_depth_mm");

# %%
penguins_fg = sns.FacetGrid(data = penguins_df, row='sex' ,col = 'island')
penguins_fg.map(sns.scatterplot, 'bill_length_mm', "flipper_length_mm");

# %%
penguins_fg = sns.FacetGrid(data = penguins_df, row='sex' ,col = 'island')
penguins_fg.map(sns.scatterplot, 'bill_depth_mm', "flipper_length_mm");

# %%
sns.relplot(
    data=penguins_df, x="bill_depth_mm", y="flipper_length_mm",
    col="sex", hue="island", style="island",
    kind="scatter"
);

# %%
sns.regplot(data= penguins_df, x = 'bill_length_mm', y ='bill_depth_mm');

# %%
sns.regplot(data= penguins_df, x = 'bill_length_mm', y ='body_mass_g');

# %%
sns.regplot(data = penguins_df, x = 'bill_depth_mm', y ='body_mass_g');

# %%
sns.regplot(data = penguins_df, x ="flipper_length_mm", y = "body_mass_g");

# %%
sns.scatterplot(data = penguins_df, x ='flipper_length_mm', y = 'body_mass_g', hue ='island', style='island');

# %%
sns.pairplot(data =penguins_df, hue='island');

# %%
sns.pairplot(data =penguins_df, hue='sex');

# %%
sns.pairplot(data =penguins_df, hue='species');
